# %% [markdown]
# 1) find gradient of  	Φ=(x^2)yz

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=v[0]**2*v[1]*v[2]
G=gradient(F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Gradient of F=")
display(G)
# Out:
# given scalar function F=
# x**2*y*z
# Gradient of F=
# 2*x*y*z*v.x + x**2*z*v.y + x**2*y*v.z

# %% [markdown]
# 2) find Divergence of F=[x^2y]i + [yz^2]j + [x^2z]k

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=v[0]**2*v[1]*v.x+v[1]*v[2]**2*v.y+v[0]**2*v[2]*v.z
G=divergence (F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Divergence of F=")
display(G)
# Out:
# given scalar function F=
# x**2*y*v.x + y*z**2*v.y + x**2*z*v.z
# Divergence of F=
# x**2 + 2*x*y + z**2

# %% [markdown]
# 3) prove that the vector (yz-x^2)i + (4y-(z^2)x)j + (2xz-4z)k is solenoidal

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=((v[1]*v[2]-v[0]**2))*v.x + (4*v[1]-(v[2]**2)*v[0])*v.y + (2*v[0]*v[2]-4*v[2])*v.z
G=divergence (F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Divergence of F=")
display(G)
# Out:
# given scalar function F=
# (-x**2 + y*z)*v.x + (-x*z**2 + 4*y)*v.y + (2*x*z - 4*z)*v.z
# Divergence of F=
# 0

# %% [markdown]
# 4)Find the curl of F=[xy^2]i + [2(x^2)yz]j - [3yz^2]k

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=(v[0]*v[1]**2)*v.x + 2*((v[0]**2)*v[1]*v[2])*v.y - (3*v[1]*v[2]**2)*v.z
G=curl (F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given vector function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Curl of F=")
display(G)
# Out:
# given vector function F=
# x*y**2*v.x + 2*x**2*y*z*v.y - 3*y*z**2*v.z
# Curl of F=
# (-2*x**2*y - 3*z**2)*v.x + (4*x*y*z - 2*x*y)*v.z

# %% [markdown]
# 5) show that F=(4xy-z^3)i + 2x^2j + 3xz^2k  is irrotational

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=(4*v[0]*v[1]-v[2]**3)*v.x + 2*(v[0]**2)*v.y - (3*v[0]*v[2]**2)*v.z
G=curl (F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Curl of F=")
display(G)
# Out:
# given scalar function F=
# (4*x*y - z**3)*v.x + 2*x**2*v.y - 3*x*z**2*v.z
# Curl of F=
# 0

# %% [markdown]
# 6) if u=x+y+z, v=x^2+y^2+z^2, w=yz+zx+xy, find grad u, grad v, grad z

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
u=v[0]+v[1]+v[2]
Gu=gradient(u,v)
u=u.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function u=")
display(u)
Gu=Gu.subs([(v[0],x),(v[1],y),(v[2],z)])
print("gradient of u=")
display(Gu)

V=v[0]**2+v[1]**2+v[2]**2
GV=gradient(V,v)
V=V.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function V=")
display(V)
GV=GV.subs([(v[0],x),(v[1],y),(v[2],z)])
print("gradient of V=")
display(GV)

w=v[1]*v[2]+v[2]*v[0]+v[0]*v[1]
Gw=gradient(w,v)
w=w.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function w=")
display(w)
Gw=Gw.subs([(v[0],x),(v[1],y),(v[2],z)])
print("gradient of w=")
display(Gw)
# Out:
# given scalar function u=
# x + y + z
# gradient of u=
# v.x + v.y + v.z
# given scalar function V=
# x**2 + y**2 + z**2
# gradient of V=
# 2*x*v.x + 2*y*v.y + 2*z*v.z
# given scalar function w=
# x*y + x*z + y*z
# gradient of w=
# (y + z)*v.x + (x + z)*v.y + (x + y)*v.z

# %% [markdown]
# 7) find divF and curlF at the point(1,2,3), given that F= [(x^2)yz]i + [x(y^2)z]j + [xy(z^2)]k

# %%
from sympy.physics.vector import *
from sympy import var
var('x,y,z')
v= ReferenceFrame ('v')
F=v[0]**2*v[1]*v[2]*v.x + v[0]*(v[1]**2)*v[2]*v.y + v[0]*v[1]*v[2]**2*v.z
G=divergence (F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("given scalar function F=")
display(F)
G=G.subs([(v[0],x),(v[1],y),(v[2],z)])
print("Divergence of F=")
display(G)
G=G.subs([(x,1),(y,2),(z,3)])
print("divergence of F at (1,2,3) is")

F=v[0]**2*v[1]*v[2]*v.x + v[0]*(v[1]**2)*v[2]*v.y + v[0]*v[1]*v[2]**2*v.z
G=curl(F,v)
F=F.subs([(v[0],x),(v[1],y),(v[2],z)])
print("curl of F=")
display(F)
G=G.subs([(x,1),(y,2),(z,3)])
print("divergence of F at(1,2,3) is")
display(G)
# Out:
# given scalar function F=
# x**2*y*z*v.x + x*y**2*z*v.y + x*y*z**2*v.z
# Divergence of F=
# 6*x*y*z
# divergence of F at (1,2,3) is
# curl of F=
# x**2*y*z*v.x + x*y**2*z*v.y + x*y*z**2*v.z
# divergence of F at(1,2,3) is
# (-v_x*v_y**2 + v_x*v_z**2)*v.x + (v_x**2*v_y - v_y*v_z**2)*v.y + (-v_x**2*v_z + v_y**2*v_z)*v.z
